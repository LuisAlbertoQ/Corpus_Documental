# %%
import pandas as pd
from pathlib import Path
import chromadb
from sentence_transformers import SentenceTransformer

# Rutas
VECTOR_STORE = Path("/home/jupyteruser/work/vector_store")

# Cargar modelo y base de datos
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
client = chromadb.PersistentClient(path=str(VECTOR_STORE))
collection = client.get_collection("corpus_upeu")

# Consulta que quieras probar
#pregunta = "¿Qué requisitos necesito para graduarme?"
pregunta = "¿Cuáles son los derechos del estudiante unionista?"

# Generar embedding
query_embedding = model.encode([pregunta])[0].tolist()

# Buscar
resultados = collection.query(
    query_embeddings=[query_embedding],
    n_results=3,
    include=["documents", "metadatas", "distances"]
)

# Mostrar resultados
for i, (doc, meta, dist) in enumerate(zip(resultados['documents'][0],
                                          resultados['metadatas'][0],
                                          resultados['distances'][0])):
    print(f"\n--- Resultado {i+1} (distancia coseno: {dist:.4f}) ---")
    print(f"Documento fuente: {meta['documento']}")
    print(f"Categoría: {meta['categoria']}")
    print(f"Texto completo del fragmento:\n{doc}\n")
# Out:
# /usr/local/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# --- Resultado 1 (distancia coseno: 0.2938) ---
# Documento fuente: REGLAMENTO DEFENSORIA UNIVERSITARIA 2025 v4
# Categoría: A
# Texto completo del fragmento:
# Artículo 10°
# Velar por los derechos y libertades de los integrantes de la comunidad universitaria. 10.18. Otras que la Ley, el Estatuto y los reglamentos de la UPeU determinen.
#
#
# --- Resultado 2 (distancia coseno: 0.3195) ---
# Documento fuente: REGLAMENTO RESIDENCIAS UNIVERSITARIAS
# Categoría: D
# Texto completo del fragmento:
# Artículo 48°
# la residencia, sin permiso. 48.3.23. Promover o participar de eventos que conduzcan a la discriminación o bullying por cualquier medio, dirigida a cualquier miembro de la comunidad universitaria. 48.3.24. Segunda reincidencia de falta grave. 48.3.25. Otras establecidas en el Reglamento del Estudiante Unionista, el
#
#
# --- Resultado 3 (distancia coseno: 0.3232) ---
# Documento fuente: ESTATUTO 2024. 04-09-2024
# Categoría: A
# Texto completo del fragmento:
# Artículo 112°
# . Derechos del estudiante. Son derechos de los estudiantes los siguientes: 112.1. Acceso libre al campus universitario, sus instalaciones, a las actividades académicas y de investigación programadas; excepto, durante los tiempos, a los lugares y las situaciones restringidos por 112.2. Participar, durante cada semestre, en la evaluación a los docentes 112.3. Participar en el gobierno y evaluación de la actividad académica, durante los procesos electorales universitarios según el reglamento respectivo.
#
# 112.4. Recibir formación académica de calidad, conocimientos generales, herramientas de investigación, cultura y de servicio social, y una formación de valores cristianos.
#
# 112.5. Recibir distinciones y estímulos por meritorios trabajos de investigación y creación, así como por aprovechamiento, mientras duren sus estudios.
#
# 112.6. Recibir la visita de sus docentes, personal administrativo y otros en su residencia.
#
# 112.7. Ser escuchado en un eventual proceso disciplinario y presentar los recursos que la ley y los reglamentos establecen.
#
# 112.8. Usar los servicios académicos, de bienestar y asistencia, ofertados por la UPeU, previo cumplimiento de los requisitos académicos, financieros y administrativos.
#
# 112.9. Otros dispuestos por la ley, el Estatuto y normas correspondientes.
# . Deberes del estudiante. Son deberes de los estudiantes: 113.1. Contribuir en la solución de los problemas y necesidades de la comunidad local, la sociedad y el país, mediante el estudio, la investigación, la misión, extensión cultural y la proyección social.
#
# 113.2. Contribuir en el prestigio e identidad, la realización de los fines y cumplimiento de los principios de la UPeU.
#
# 113.3. Cumplir sus compromisos financieros contraídos con la UPeU.
#
# 113.4. Dedicarse con esfuerzo y responsabilidad al estudio y, en forma continua, a su formación humana, social, académica y profesional.
#
# 113.5. Elegir a sus representantes ante los órganos de gobierno de la UPeU.
#
# 113.6. Participar activamente en los eventos académicos, espirituales, culturales, deportivos y sociales que programe la UPeU en su vida 113.7. Respetar los derechos de los miembros de la comunidad 113.8. Otros que señalen la ley, el presente Estatuto y los reglamentos de
