# %%
import pandas as pd
from pathlib import Path
import chromadb
from sentence_transformers import SentenceTransformer

# Rutas
VECTOR_STORE = Path("/home/jupyteruser/work/vector_store")

# Cargar modelo y base de datos
model = SentenceTransformer('paraphrase-multilingual-mpnet-base-v2')
client = chromadb.PersistentClient(path=str(VECTOR_STORE))
collection = client.get_collection("corpus_upeu")

# Consulta que quieras probar
#pregunta = "¿Qué requisitos necesito para graduarme?"
pregunta = "¿Qué requisitos necesito para obtener una beca en la UPeU?"

# Generar embedding
query_embedding = model.encode([pregunta])[0].tolist()

# Buscar
resultados = collection.query(
    query_embeddings=[query_embedding],
    n_results=3,
    include=["documents", "metadatas", "distances"]
)

# Mostrar resultados
for i, (doc, meta, dist) in enumerate(zip(resultados['documents'][0],
                                          resultados['metadatas'][0],
                                          resultados['distances'][0])):
    print(f"\n--- Resultado {i+1} (distancia coseno: {dist:.4f}) ---")
    print(f"Documento fuente: {meta['documento']}")
    print(f"Categoría: {meta['categoria']}")
    print(f"Texto completo del fragmento:\n{doc}\n")
# Out:
# /usr/local/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# --- Resultado 1 (distancia coseno: 0.1566) ---
# Documento fuente: REGLAMENTO BECAS 2021 ACTUALIZADO
# Categoría: B
# Texto completo del fragmento:
# Artículo 49°
# Artículo 49°. Para el otorgamiento de la beca, el estudiante presenta los siguientes requisitos: 49.1. Tener la calidad de estudiante regular de la UPeU. 49.2. Haber obtenido un promedio ponderado mínimo de catorce (14) y el cien 49.3. No haber sido ni estar sancionado en el semestre académico precedente ni 49.4. No adeudar a la UPeU por ningún concepto. 49.5. Mostrar los documentos de identidad (DNI/CE) del padre, madre, estudiante y hermanos dependientes. 49.6. El responsable de la economía familiar (padre, madre o apoderados) deberá presentar los siguientes documentos, de acuerdo con su situación: 49.6.1. Dependiente: Tres (3) últimas boletas de pago. 49.6.2. Independiente: Reporte de recibos por honorarios electrónicos emitidos en los últimos tres meses (Ingresar con Clave Sol a Intranet de SUNAT). 49.6.3. Pensionistas: Tres (3) últimas boletas de pensión. 49.6.4. Negocio propio: PDT o RUS de los tres (3) últimos meses. 49.6.5. Ingresos por alquiler de inmueble o renta de auto: Contrato de alquiler de los mismos. 49.6.6. Remesas familiares: Voucher de los tres (3) últimos meses. 49.6.7. Trabajadores informales: Declaración Jurada de Ingresos indicando la actividad y el ingreso promedio (E
#
#
# --- Resultado 2 (distancia coseno: 0.1896) ---
# Documento fuente: REGLAMENTO DE ESTUDIOS V5_2025
# Categoría: B
# Texto completo del fragmento:
# Artículo 51º
# Obligatoriedad de obtener totalidad de créditos. Para tener la calidad o condición de egresado de la UPeU, el estudiante acumulativamente además de los requisitos curriculares, académicos, debe haber aprobado el mínimo de créditos exigidos por el diseño curricular, currículo y plan de estudios de acuerdo con la naturaleza, modalidad, nivel de estudios realizados y además cumplir con los requisitos académicos administrativos correspondientes.
# Número mínimo de créditos académicos. El número mínimo de créditos que el estudiante debe cursar obligatoriamente en toda su vida académica en una carrera profesional o programa de estudios, conducente a obtener un grado o título, sin perjuicio de los académicos y administrativos, es en estudios de pregrado:
#
# 52.1. Carreras profesionales en general, mínimo doscientos (200) créditos.
#
# 52.2. Carrera de Medicina Humana, mínimo trescientos cincuenta y cuatro (354) o trescientos sesenta y cuatro (364) créditos, según al año de ingreso o cohorte.
#
# 52.3. Carrera profesional de derecho, mínimo doscientos cuarenta y cinco (245) o doscientos sesenta (260) créditos, según al año de ingreso o cohorte.
#
# 52.4. Segunda Especialidad Profesional, mínimo cuarenta (40) créditos. Las de medicina humana, según el mínimo de la especialidad determinado en la norma vigente.
# Modificación o reajuste de créditos académicos. El número mínimo de créditos obligatorios según el diseño curricular, currículo y plan de estudios puede ser modificado, pero no respecto del mínimo legal.
#
# La modificación se aplica a la promoción de ingreso siguiente y no de forma retroactiva a promociones anteriores, salvo errores de transcripción o cómputo.
#
# DE LA CARGA ACADÉMICA DEL ESTUDIANTE
#
#
# --- Resultado 3 (distancia coseno: 0.2017) ---
# Documento fuente: REGLAMENTO BECAS 2021 ACTUALIZADO
# Categoría: B
# Texto completo del fragmento:
# Artículo 56°
# . Para el otorgamiento de la beca y sus beneficios, el estudiante solicitante debe cumplir y presentar los siguientes requisitos específicos:
#
# 56.1. Tener la calidad de estudiante regular de la UPeU.
#
# 56.2. Documentos oficiales emitidos por las entidades gubernamentales respectivas que acredite su procedencia, pertenencia y calidad de miembro, integrante, constituyente, de una comunidad, o pueblo indígena, nativa o aborigen o campesina en un nivel o situación socioeconómica de vulnerabilidad o riesgo oficialmente reconocida.
#
# 56.3. No tener deuda pendiente con la UPeU por ningún concepto.
#
# 56.4. Declaración jurada 56.5. Ficha socioeconómica, constancias / certificados u otros documentos que
# . Para la renovación del descuento el estudiante obligatoriamente debe cumplir y
#
# 57.1. Constancia de estudios del estudiante beneficiario.
#
# 57.2. No haber sido ni estar sancionado en el semestre académico precedente ni 57.3. Haber obtenido un promedio ponderado mínimo de catorce (14) y el cien 57.4. No adeudar a la UPeU por ningún concepto.
#
# 57.5. Ficha socioeconómica, constancias / certificados u otros documentos que
#
# Subcapítulo VI DE LA BECA POR DISCAPACIDAD
#
# Qué es la beca por discapacidad
# . Es aquella beca que concede la UPeU, previa evaluación, a los estudiantes que presentan una discapacidad permanente, que estén aptos para cursar el segundo año de la carrera profesional universitaria.
#
# Cuál es el monto y cómo se aplica la beca y sus beneficios
