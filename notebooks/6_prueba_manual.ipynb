# %%
import pandas as pd
from pathlib import Path
import chromadb
from sentence_transformers import SentenceTransformer

# Rutas
VECTOR_STORE = Path("/home/jupyteruser/work/vector_store")

# Cargar modelo y base de datos
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
client = chromadb.PersistentClient(path=str(VECTOR_STORE))
collection = client.get_collection("corpus_upeu")

# Consulta que quieras probar
#pregunta = "¿Qué requisitos necesito para graduarme?"
pregunta = "¿cuantas escuelas profecionales hay en la upeu?"

# Generar embedding
query_embedding = model.encode([pregunta])[0].tolist()

# Buscar
resultados = collection.query(
    query_embeddings=[query_embedding],
    n_results=3,
    include=["documents", "metadatas", "distances"]
)

# Mostrar resultados
for i, (doc, meta, dist) in enumerate(zip(resultados['documents'][0],
                                          resultados['metadatas'][0],
                                          resultados['distances'][0])):
    print(f"\n--- Resultado {i+1} (distancia coseno: {dist:.4f}) ---")
    print(f"Documento fuente: {meta['documento']}")
    print(f"Categoría: {meta['categoria']}")
    print(f"Texto completo del fragmento:\n{doc}\n")
# Out:
# /usr/local/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# --- Resultado 1 (distancia coseno: 0.4226) ---
# Documento fuente: ESTATUTO 2024. 04-09-2024
# Categoría: A
# Texto completo del fragmento:
# Artículo 107°
# Artículo 107°. Obligaciones del docente. Además de los establecidos en la ley y los reglamentos, los docentes tienen las obligaciones siguientes: 107.1. Apoyar el cumplimiento misional de la UPeU. 107.2. Cumplir con las normas estatutarias, los reglamentos, el marco axiológico, misional y fines de la educación cristiana adventista de 107.3. Desarrollar con libertad, pensamiento crítico, idoneidad y responsabilidad, las funciones asignadas y naturales de la docencia, en el marco de la filosofía de la educación cristiana adventista. 107.4. Desarrollar su labor docente con rigurosidad académica y metodológica, cumpliendo los lineamientos curriculares, contenidos y requerimientos académicos de los sílabos, tutoría, evaluación y otras. 107.5. Desempeñar y reportar las responsabilidades académicas y administrativas asignadas por las diversas instancias de la UPeU, bajo responsabilidad. 107.6. Desarrollar la investigación, innovación y la producción intelectual como parte del quehacer de la enseñanza-aprendizaje en los campos de la ciencia, tecnología, humanidades y artes, señalando su filiación. 107.7. Ejecutar actividades de misión, extensión cultural y proyección social conforme al diseño curricular y el plan operativo. 107.8. Mantener un nivel de perfeccionamiento profesional permanentemente y activo, acorde al avance de la ciencia
#
#
# --- Resultado 2 (distancia coseno: 0.4547) ---
# Documento fuente: REGLAMENTO GENERAL UPeU 2023
# Categoría: A
# Texto completo del fragmento:
# CAPÍTULO II
# DEL MARCO FILOSÓFICO, AXIOLÓGICO Y PROPÓSITOS
# . Fundamento. La filosofía de la educación cristiana adventista es la piedra angular en la planificación, desarrollo, implementación y evaluación de la actividad formativa, educativa, en los programas de estudios de pregrado o
