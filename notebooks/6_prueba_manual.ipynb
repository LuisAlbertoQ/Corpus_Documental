# %%
import pandas as pd
from pathlib import Path
import chromadb
from sentence_transformers import SentenceTransformer

# Rutas
VECTOR_STORE = Path("/home/jupyteruser/work/vector_store")

# Cargar modelo y base de datos
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
client = chromadb.PersistentClient(path=str(VECTOR_STORE))
collection = client.get_collection("corpus_upeu")

# Consulta que quieras probar
#pregunta = "¿Qué requisitos necesito para graduarme?"
pregunta = "¿Cual es el costo de tramite para el derecho de adminsion de medicina hunama?"

# Generar embedding
query_embedding = model.encode([pregunta])[0].tolist()

# Buscar
resultados = collection.query(
    query_embeddings=[query_embedding],
    n_results=3,
    include=["documents", "metadatas", "distances"]
)

# Mostrar resultados
for i, (doc, meta, dist) in enumerate(zip(resultados['documents'][0],
                                          resultados['metadatas'][0],
                                          resultados['distances'][0])):
    print(f"\n--- Resultado {i+1} (distancia coseno: {dist:.4f}) ---")
    print(f"Documento fuente: {meta['documento']}")
    print(f"Categoría: {meta['categoria']}")
    print(f"Texto completo del fragmento:\n{doc}\n")
# Out:
# /usr/local/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# --- Resultado 1 (distancia coseno: 0.3750) ---
# Documento fuente: REGLAMENTO INTERNO DE TRABAJO Final 2020
# Categoría: A
# Texto completo del fragmento:
# caso de enfermedad, la UPeU podrá a su discreción y autono- mía efectuar la verificación de la declaración en: la institución de salud, el al domicilio o lugar donde esté ubicado el trabajador o el profesional de salud, por parte de la DTH y requerir la presentación de la consulta, prescripción (receta) médica y el comprobante de pago de la prescripción (receta) médica. El trabajador está en la obligación de colaborar efectivamente en la verifica- ción, salvo exista una prescripción médica de imposibilidad física de contacto. Artículo 81. Falsedad de hechos, estado o situación declarada en la informa- ción. El trabajador que proporcione información falsa sobre hechos, estados o situaciones o documentarios tales como: certificados de incapacidad o cer- tificados médicos, constancias, certificaciones y similares o análogos, adulte- rados, inexistentes, no vigentes o caducos aduciendo enfermedad inexistente a fin de no asistir a su trabajo, será sancionado con despido por causa justa, al configurarse falta grave. Página 45 Sé íntegro, Sé misionero, Sé Innovador Artículo 82. Quebrantamiento de la buena fe laboral. El trabajador a quien se le asigna roles, funciones, actividades, comisiones o similares de trabajo y es sorprendido por su jefe inmediato superior, o si los he- chos, evidencias, referencias o la situación configura el incumplimiento laboral asignado por realizar actividades ajenas en el horario de trabajo, presupone la infracción a la buena fe laboral y causa justa de despido, conforme a ley y el RIT. CAPÍTULO VI: DE LAS REMUNERACIONES Y BENEFICIOS SOCIALES SUBCAPÍTULO I: DE LAS REMUNERACIONES Artículo 83. Intangibilidad
#
#
# --- Resultado 2 (distancia coseno: 0.4242) ---
# Documento fuente: TUPA V6 2023 UPeU
# Categoría: E
# Texto completo del fragmento:
# DERECHO DE TRÁMITE PERIODO O ADMISIÓN PROCESO / INSTANCIA () Denegatoria, incumplimiento de plazos. 1ra Instancia: Unidad de Posgrado. 2da Instancia: Consejo de Escuela de Posgrado PLAZO Y/O ENTREGA ÁREA RESPONSABLE Página 43 PROCESO DE TESIS PARA OPTAR EL GRADO DE DOCTOR 1. Solicitud (MS 04), indicando número de voucher y fecha de pago (S/.) S/ 450.00 TODO EL AÑO 1. Pago en efectivo en caja UPeU o en cuenta Banco BBVA o BCP 2. El Maestro solicita la asesoría del Proyecto de tesis con la documentación requerida. 3. La coordinación de Investigación de la UPG gestiona a través del Consejo de la UPG la aprobación en el consejo de la EPG. 06 meses después de ser aprobado por el Consejo de la EPG Dirección de Investigación de la EPG 1. Solicitud de dictaminadores (MS-06). 2. Presenta carta de conformidad del asesor(a) DGI-04. 3. Tres (3) ejemplares de su proyecto de tesis. Sin costo (S/. 00) Dentro del plazo de los 06 meses 1. El Maestro solicita el dictamen del Proyecto de tesis con la documentación requerida. 2. La coordinación de Investigación de la UPG gestiona a través del Consejo de la UPG su aprobación en el consejo de la EPG. 15 días hábiles después de ser aprobado por el Consejo EPG Dirección de Investigación de la EPG 1. Solicitud de inscripción del proyecto (MS-09), indicando número de voucher y fecha de pago por asesoría de Tesis. 2. Dictámenes aprobatorios del Proyecto de tesis (DGI-05). 3. Ficha de Inscripción del Proyecto de Tesis (DGI- 06). S/ 1,300.00 Inmediata 1. Pago en efectivo en caja UPeU o en cuenta Banco
#
#
# --- Resultado 3 (distancia coseno: 0.4358) ---
# Documento fuente: TUPA V6 2023 UPeU
# Categoría: E
# Texto completo del fragmento:
# adicionales en la web. S/. 250.00 Solo en período de convocatorias de admisión. En el período específico determinado para la Carrera de Medicina Humana 1. Inscripción en línea. 2. Pago en efectivo en caja UPeU o en cuenta Banco BBVA o BCP. Precisar en la solicitud el número de voucher y fecha de pago por derecho de trámite 3. Entrega de documentos en Oficina de Admisión solo el campus Lima. Inmediato en días y horas hábiles Oficina de Admisión campus Lima, Juliaca o Tarapoto 1ra Instancia: Admisión. 2da Instancia: Secretaria General. 1.2 Derecho de Admisión Regular Requisitos Generales: 1. Copia CE o Pasaporte para extranjeros. 2. Copia legible de Partida de nacimiento. 3. Certificado original de estudios de educación básica secundaria o educación básica alternativa o su equivalente para extranjeros (revalidados en el Perú ante el Ministerio de Educación). 4. N Voucher y fecha de pago por derecho de admisión. S/. 220.00 Solo en período de convocatorias de admisión. 1. Inscripción en línea. 2. Pago en efectivo en caja UPeU o en cuenta Banco BBVA o BCP. Precisar en la solicitud el número de voucher y fecha de pago por derecho de trámite 3. Entrega de documentos en Oficina Admisión en el campus Lima, Juliaca o Tarapoto. 1.3 Pre-Ingreso Colegios Red Promotora de la S/. 120.00 1ra Instancia: Admisión. 2da Instancia: Secretaria General, Campus Lima / Campus Juliaca y Tarapoto: Secretaría académica. 1.4 Pre-Ingreso Proyecto Sueña en Grande S/. 120.00 Página 4 1.5 Cambio de Carrera Después de la Inscripción Requisitos adicionales Carrera Profesional de Teología: 1. Resumen Experiencia Ec
